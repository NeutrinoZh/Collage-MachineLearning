# %% [markdown]
# # <center> Практична робота 01 </center> <center> Місце та задачі машинного навчання </center>

# %% [markdown]
# ___Завдання:___ cформувати блокнот Jupyter Notebook для розвідувального аналізу даних
#
# ___За прострочку___ додаткове завдання: доповнити блокнот 5ма математичними формулами, записаними за допомогою LaTEX-нотації

# %% [markdown]
# ### <p style='text-align: right;'> Виконав студент групи <ins>1П-20</ins> </p><p style='text-align: right;'> <ins>Прізвище Ім'я По батькові</ins> </p>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


# зчитуємо дані з датасету.
url = 'https://raw.githubusercontent.com/Kaushik-Varma/Marketing_Data_Analysis/master/Marketing_Analysis.csv'
data= pd.read_csv(url, low_memory=False)

# виводимо дані (перші 20 записів)
data.head(20)
# Out:
#        banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0   customer id and age.        NaN  Customer salary and balance.        NaN
# 1             customerid        age                        salary    balance
# 2                      1         58                        100000       2143
# 3                      2         44                         60000         29
# 4                      3         33                        120000          2
# 5                      4         47                         20000       1506
# 6                      5         33                             0          1
# 7                      6         35                        100000        231
# 8                      7         28                        100000        447
# 9                      8         42                        120000          2
# 10                     9         58                         55000        121
# ...
